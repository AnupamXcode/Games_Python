# %%
import random

# %%
import random
# Generate a random number between 1 and 10
num = random.randint(1, 10)
count = 0
print("Guess the Number (between 1 and 10):")
while True:
    a = int(input("Enter your guess: "))
    count += 1
    if a == num:
        print(f"🎉 Congratulations! You guessed it right, it's {num}.")
        print(f"You guessed the number in {count} attempts.")
        break
    elif a < num:
        print("Too low! Try again.")
    else:
        print("Too high! Try again.")
# Out:
# Guess the Number (between 1 and 10):
# Enter your guess: 1
# Too low! Try again.
# Enter your guess: 5
# Too low! Try again.
# Enter your guess: 9
# Too low! Try again.
# Enter your guess: 10
# 🎉 Congratulations! You guessed it right, it's 10.
# You guessed the number in 4 attempts.
